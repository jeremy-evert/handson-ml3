# %% [markdown]
# # 04 – Temperature Data Fusion and Consensus Modeling
#
# ## Objective
#
# This notebook builds a simple machine learning-inspired data fusion model.
#
# We will:
#
# - Construct a weighted average temperature estimate
# - Experiment with bias correction
# - Train a linear regression fusion model
# - Evaluate fusion performance against individual agencies
#
# The goal is to estimate a "consensus temperature" using multiple independent observational sources.
#
# This notebook introduces core ideas in:
#
# - Ensemble modeling
# - Data fusion
# - Model weighting
# - Error minimization
# - Practical machine learning design
